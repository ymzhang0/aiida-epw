# %%
from aiida import load_profile
from aiida_epw.data import (DosData, A2fData, GapFunctionData)

load_profile()
# Out:
# Profile<uuid='fbf9eecf18344ac8891ef19c524dc8df' name='dev'>

# %%
eldos = DosData.from_file("/Users/yimingzhang/Developer/aiida-plugins/aiida-epw/tests/files/tools/parsers/a2f/aiida.dos")

# %%
eldos.get_energy()
# Out:
# array([10.87119041, 10.88119041, 10.89119041, 10.90119041, 10.91119041,
#        10.92119041, 10.93119041, 10.94119041, 10.95119041, 10.96119041,
#        10.97119041, 10.98119041, 10.99119041, 11.00119041, 11.01119041,
#        11.02119041, 11.03119041, 11.04119041, 11.05119041, 11.06119041,
#        11.07119041, 11.08119041, 11.09119041, 11.10119041, 11.11119041,
#        11.12119041, 11.13119041, 11.14119041, 11.15119041, 11.16119041,
#        11.17119041, 11.18119041, 11.19119041, 11.20119041, 11.21119041,
#        11.22119041, 11.23119041, 11.24119041, 11.25119041, 11.26119041,
#        11.27119041, 11.28119041, 11.29119041, 11.30119041, 11.31119041,
#        11.32119041, 11.33119041, 11.34119041, 11.35119041, 11.36119041,
#        11.37119041, 11.38119041, 11.39119041, 11.40119041, 11.41119041,
#        11.42119041, 11.43119041, 11.44119041, 11.45119041, 11.46119041,
#        11.47119041, 11.48119041, 11.49119041, 11.50119041, 11.51119041,
# ...

# %%
a2f = A2fData.from_file("/Users/yimingzhang/Developer/aiida-plugins/aiida-epw/tests/files/tools/parsers/a2f/aiida.a2f")

# %%
a2f.get_cumulative_lambda().shape
# Out:
# (500, 10)

# %%
aniso_gap = GapFunctionData.from_directory('/Users/yimingzhang/Developer/aiida-plugins/aiida-epw/tests/files/tools/parsers/fsr_aniso_eliashberg', kind='aniso')

# %%
aniso_gap.get_temperatures()

aniso_gap.get_gap_functions()
# Out:
# {3.0: array([[3.00000060e+00, 3.09183012e+00, 3.00000000e+00, 6.01921836e-07,
#          2.67074725e-02],
#         [3.00320081e+00, 3.10569483e+00, 3.00000000e+00, 3.20080607e-03,
#          1.42020832e+02],
#         [3.00570982e+00, 3.11955954e+00, 3.00000000e+00, 5.70982464e-03,
#          2.53346822e+02],
#         [3.00000342e+00, 3.13342424e+00, 3.00000000e+00, 3.41768105e-06,
#          1.51643647e-01],
#         [3.00134910e+00, 3.14728895e+00, 3.00000000e+00, 1.34910387e-03,
#          5.98601882e+01],
#         [3.76670275e+00, 3.16115366e+00, 3.00000000e+00, 7.66702748e-01,
#          3.40188565e+04],
#         [3.14616817e+00, 3.17501837e+00, 3.00000000e+00, 1.46168167e-01,
#          6.48553029e+03],
#         [3.00000935e+00, 3.18888308e+00, 3.00000000e+00, 9.34808667e-06,
#          4.14777721e-01],
#         [3.00000000e+00, 3.20274779e+00, 3.00000000e+00, 2.00556529e-13,
#          8.89876004e-09],
# ...
